# %% [markdown]
# <a href="https://colab.research.google.com/github/YAGOPORTELAYP/AI-TaskHub---My-First-App/blob/main/APP_DR_VOICE_TRANSCRIPTOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# !pip install gradio whisper python-dotenv openai pyannote.audio spacy
# !python -m spacy download pt_core_news_lg
# !pip install kivy-deps.webview kivy
# !flutter pub add webview_flutter
# !pip install --upgrade openai
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-m1w7_wkr
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-m1w7_wkr
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# ...

# %%
# !pip install gradio

# %%
# !pip install --upgrade gradio  # Make sure Gradio is up-to-date

import gradio as gr

# ... (your other imports and functions)

iface = gr.Interface(
    fn=prever,
    inputs=gr.Audio(type="filepath"),  # Remove the 'source' argument
    outputs=["text", "text"],
    title="Gerador de Sumário e Palavras-chave",
    description="Grave um áudio para gerar um sumário e extrair palavras-chave."
)

iface.launch()
# Out:
# ...
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f3d51b613b120840ba.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f3d51b613b120840ba.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install --upgrade gradio pydub

import gradio as gr
from pydub import AudioSegment

# ... (your other imports and functions)

def prever(audio_file):
  """Função para realizar a previsão usando o modelo."""
  if modelo_mlp is not None:
    # Convert audio to MP3 if necessary
    if not audio_file.lower().endswith(".mp3"):
        audio = AudioSegment.from_file(audio_file)
        audio.export("temp.mp3", format="mp3")
        audio_file = "temp.mp3" # Update the file path

    # Assuming 'audio_file' is now an MP3 file path, load the audio data here
    # Replace this with your actual audio loading and preprocessing using librosa or other libraries
    # For example, using librosa:
    # import librosa
    # audio_data, sr = librosa.load(audio_file)
    # ... (further preprocessing) ...

    sumario = modelo_mlp.predict(audio_file) # Replace 'dados_audio' with your preprocessed audio data
    palavras_chave = modelo_mlp.predict(audio_file)  # Using the same prediction for summary and keywords for now
    return sumario, palavras_chave
  else:
    return "Modelo não carregado. Não é possível fazer previsões.", "Modelo não carregado. Não é possível fazer previsões."

iface = gr.Interface(
    fn=prever,
    inputs=gr.Audio(type="filepath"),  # Remove the 'source' argument
    outputs=["text", "text"],
    title="Gerador de Sumário e Palavras-chave",
    description="Grave um áudio para gerar um sumário e extrair palavras-chave."
)

iface.launch()
# Out:
# ...
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e721c8a708162cdea3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e721c8a708162cdea3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install --upgrade gradio pydub

import gradio as gr
from pydub import AudioSegment
import time

# ... (your other imports and functions)

def prever(audio_file):
    """Função para realizar a previsão usando o modelo."""
    if modelo_mlp is not None:
        # Convert audio to MP3 if necessary
        if not audio_file.lower().endswith(".mp3"):
            audio = AudioSegment.from_file(audio_file)
            audio.export("temp.mp3", format="mp3")
            audio_file = "temp.mp3"  # Update the file path
            # Add a delay to simulate processing and provide visual feedback
            #time.sleep(2)  # You can adjust the delay as needed
            yield "Arquivo de áudio convertido para MP3. Pronto para transcrição.", None, None # Indicate conversion is done before prediction

        # Assuming 'audio_file' is now an MP3 file path, load the audio data here
        # Replace this with your actual audio loading and preprocessing using librosa or other libraries
        # For example, using librosa:
        # import librosa
        # audio_data, sr = librosa.load(audio_file)
        # ... (further preprocessing) ...

        sumario = modelo_mlp.predict(audio_file)  # Replace 'dados_audio' with your preprocessed audio data
        palavras_chave = modelo_mlp.predict(audio_file)  # Using the same prediction for summary and keywords for now
        yield "Transcrição concluída.", sumario, palavras_chave  # Update outputs after prediction
    else:
        yield "Modelo não carregado. Não é possível fazer previsões.", None, None

iface = gr.Interface(
    fn=prever,
    inputs=gr.Audio(type="filepath"),  # Remove the 'source' argument
    outputs=[gr.Textbox(lines=1, label="Status"), "text", "text"],  # Add a Textbox for status
    title="Gerador de Sumário e Palavras-chave",
    description="Grave um áudio para gerar um sumário e extrair palavras-chave."
)

iface.queue().launch()  # Start the interface with queue for asynchronous updates
# Out:
# ...
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://72036bf8bf3fabdcbe.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://72036bf8bf3fabdcbe.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install --upgrade gradio pydub librosa  # Upgrade necessary libraries

import gradio as gr
from pydub import AudioSegment
import librosa
import numpy as np
import time
import json  # For storing and loading feedback data

# Assume modelo_mlp is defined and loaded elsewhere
# Replace with your actual model loading code
modelo_mlp = lambda x: (np.random.rand(1), np.random.rand(1))  # Placeholder, replace with your model loading

# Load or initialize feedback data
try:
    with open("feedback_data.json", "r") as f:
        feedback_data = json.load(f)
except FileNotFoundError:
    feedback_data = {}

def prever(audio_file):
    """Função para realizar a previsão usando o modelo."""
    if modelo_mlp is not None:
        # Convert audio to MP3 if necessary
        if not audio_file.lower().endswith(".mp3"):
            try:  # Handle potential file conversion errors
                audio = AudioSegment.from_file(audio_file)
                audio.export("temp.mp3", format="mp3")
                audio_file = "temp.mp3"
                yield "Arquivo de áudio convertido para MP3. Pronto para transcrição.", None, None, "0%"
            except Exception as e:
                yield f"Erro ao converter o áudio: {e}", None, None, "0%"
                return  # Stop further processing if conversion fails

        try:  # Handle potential audio loading errors
            # Get audio duration for progress bar estimation
            audio = AudioSegment.from_file(audio_file)
            duration_seconds = len(audio) / 1000

            # Simulate transcription progress with a loop
            for i in range(101):
                progress = i / 100
                time.sleep(duration_seconds / 100)
                progress_str = f"{i}%"  # String representation of progress
                yield f"Transcrevendo... {progress_str}", None, None, progress_str

            # Load and preprocess audio data using librosa
            audio_data, sr = librosa.load(audio_file)
            # ... (further preprocessing if needed) ...

            # Assuming modelo_mlp.predict works with your preprocessed data
            sumario, palavras_chave = modelo_mlp(audio_data)  # Call the model with the preprocessed data
            yield "Transcrição concluída.", str(sumario), str(palavras_chave), "100%"

        except Exception as e:
            # Record error for feedback
            error_type = type(e).__name__
            feedback_data[error_type] = feedback_data.get(error_type, 0) + 1
            with open("feedback_data.json", "w") as f:
                json.dump(feedback_data, f)

            yield f"Erro durante a previsão: {e}", None, None, "0%"

    else:
        yield "Modelo não carregado. Não é possível fazer previsões.", None, None, "0%"

iface = gr.Interface(
    fn=prever,
    inputs=gr.Audio(type="filepath"),
    outputs=[gr.Textbox(lines=1, label="Status"), "text", "text", gr.Textbox(label="Progress")],
    title="Gerador de Sumário e Palavras-chave",
    description="Grave um áudio para gerar um sumário e extrair palavras-chave."
)

iface.queue().launch()
# Out:
# ...
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://2323589ede4f1d0309.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2323589ede4f1d0309.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install --upgrade gradio pydub librosa  # Upgrade necessary libraries

import gradio as gr
from pydub import AudioSegment
import librosa
import numpy as np
import time
import json  # For storing and loading feedback data

# Assume modelo_mlp is defined and loaded elsewhere
# Replace with your actual model loading code
modelo_mlp = lambda x: (np.random.rand(1), np.random.rand(1))  # Placeholder, replace with your model loading

# Load or initialize feedback data
try:
    with open("feedback_data.json", "r") as f:
        feedback_data = json.load(f)
except FileNotFoundError:
    feedback_data = {}

def prever(audio_file):
    """Função para realizar a previsão usando o modelo."""
    if modelo_mlp is not None:
        # Convert audio to MP3 if necessary
        if not audio_file.lower().endswith(".mp3"):
            try:  # Handle potential file conversion errors
                audio = AudioSegment.from_file(audio_file)
                audio.export("temp.mp3", format="mp3")
                audio_file = "temp.mp3"
                yield "Arquivo de áudio convertido para MP3. Pronto para transcrição.", None, None, "0%"
            except Exception as e:
                yield f"Erro ao converter o áudio: {e}", None, None, "0%"
                return  # Stop further processing if conversion fails

        try:  # Handle potential audio loading errors
            # Get audio duration for progress bar estimation
            audio = AudioSegment.from_file(audio_file)
            duration_seconds = len(audio) / 1000

            # Simulate transcription progress with a loop
            for i in range(101):
                progress = i / 100
                time.sleep(duration_seconds / 100)
                progress_str = f"{i}%"  # String representation of progress
                yield f"Transcrevendo... {progress_str}", None, None, progress_str

            # Load and preprocess audio data using librosa
            audio_data, sr = librosa.load(audio_file)
            # ... (further preprocessing if needed) ...

            # Assuming modelo_mlp.predict works with your preprocessed data
            sumario, palavras_chave = modelo_mlp(audio_data)  # Call the model with the preprocessed data
            yield "Transcrição concluída.", str(sumario), str(palavras_chave), "100%"

        except Exception as e:
            # Record error for feedback
            error_type = type(e).__name__
            feedback_data[error_type] = feedback_data.get(error_type, 0) + 1
            with open("feedback_data.json", "w") as f:
                json.dump(feedback_data, f)

            yield f"Erro durante a previsão: {e}", None, None, "0%"

    else:
        yield "Modelo não carregado. Não é possível fazer previsões.", None, None, "0%"

iface = gr.Interface(
    fn=prever,
    inputs=gr.Audio(type="filepath", sources=["microphone", "upload"]),  # Specify sources within the 'inputs' argument
    outputs=[gr.Textbox(lines=1, label="Status"), "text", "text", gr.Textbox(label="Progress")],
    title="Gerador de Sumário e Palavras-chave",
    description="Grave um áudio para gerar um sumário e extrair palavras-chave."
)

iface.queue().launch()
# Out:
# ...
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://d169f2e7c7a074a0fd.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d169f2e7c7a074a0fd.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
iface = gr.Interface(
    fn=prever,
    inputs=gr.Audio(type="filepath", sources=["microphone", "upload"]),  # Specify sources within the 'inputs' argument
    outputs=[gr.Textbox(lines=1, label="Status"), "text", "text", gr.Textbox(label="Progress")],
    title="Gerador de Sumário e Palavras-chave",
    description="Grave um áudio para gerar um sumário e extrair palavras-chave."
)

iface.queue().launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b9c975bd2211013360.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b9c975bd2211013360.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
outputs=[gr.Textbox(lines=1, label="Status"), "text", "text", gr.Textbox(label="Progress")]

# %%
import whisper

# ... (código para carregar o modelo)

def prever(audio_file):
    # ... (código para conversão de áudio, se necessário)

    try:
        # ... (código para atualização de progresso)

        # Transcrever o áudio usando o Whisper
        model = whisper.load_model("base")  # Carregar o modelo Whisper
        result = model.transcribe(audio_file)  # Transcrever o áudio
        transcricao = result["text"]

        # ... (pré-processar transcricao e extrair palavras-chave)

        # Executar a previsão com o modelo carregado
        sumario, palavras_chave = modelo_mlp(transcricao_pre_processada)

        yield "Transcrição concluída.", str(sumario), str(palavras_chave), "100%"

    except Exception as e: # Added except block to handle errors
        # ... (código para tratamento de erros)
        print(f"Erro durante a transcrição: {e}") # Example error handling
        yield f"Erro durante a transcrição: {e}", None, None, "0%" # Return error message to the interface

# %%
# !pip install --upgrade gradio pydub librosa pyspellchecker  # Install necessary libraries

import gradio as gr
from pydub import AudioSegment
import librosa
import numpy as np
import time
import json
from spellchecker import SpellChecker

# ... (your other imports and functions)

# Initialize spell checker
spell = SpellChecker(language='pt')  # Use 'pt' for Portuguese

def prever(audio_file):
    # ... (your existing code for audio conversion and preprocessing)

    try:
        # ... (your existing code for progress updates)

        # Transcrever o áudio usando o Whisper
        model = whisper.load_model("base")
        result = model.transcribe(audio_file)
        transcricao = result["text"]

        # Apply spelling correction
        transcricao_corrigida = spell.correction(transcricao)

        # ... (your existing code for prediction using modelo_mlp)

        yield "Transcrição concluída.", str(sumario), str(palavras_chave), "100%", transcricao_corrigida  # Include corrected transcription in the output

    except Exception as e:
        # ... (your existing error handling code)
        # This is where the indented block needs to be
        print(f"An error occurred: {e}") # Print the error for debugging
        yield f"Erro: {e}", None, None, "0%", None  # Yield an error message and reset progress

iface = gr.Interface(
    fn=prever,
    inputs=gr.Audio(type="filepath", sources=["microphone", "upload"]),
    outputs=[
        gr.Textbox(lines=1, label="Status"),
        "text",
        "text",
        gr.Textbox(label="Progress"),
        gr.Textbox(lines=5, label="Transcrição Corrigida")  # Add a Textbox for the corrected transcription
    ],
    title="Gerador de Sumário e Palavras-chave",
    description="Grave um áudio para gerar um sumário e extrair palavras-chave."
)

iface.queue().launch()
# Out:
# ...
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b3ab0423ce55796842.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b3ab0423ce55796842.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# !pip install --upgrade gradio pydub librosa pyspellchecker  # Install necessary libraries

import gradio as gr
from pydub import AudioSegment
import librosa
import numpy as np
import time
import json
from spellchecker import SpellChecker
import whisper

# ... (your other imports and functions)

# Initialize spell checker
spell = SpellChecker(language='pt')  # Use 'pt' for Portuguese

# Assume modelo_mlp is defined and loaded elsewhere
# Replace with your actual model loading code
# modelo_mlp = lambda x: (np.random.rand(1), np.random.rand(1))  # Placeholder, replace with your model loading


def prever(audio_file):
    """Função para realizar a previsão usando o modelo."""
    # ... (your existing code for audio conversion and preprocessing)

    try:
        # ... (your existing code for progress updates)

        # Transcrever o áudio usando o Whisper
        model = whisper.load_model("base")
        result = model.transcribe(audio_file)
        transcricao = result["text"]

        # Apply spelling correction
        transcricao_corrigida = spell.correction(transcricao)

        # ----> Replace this with your actual prediction logic <----
        # Assuming modelo_mlp.predict works with your preprocessed data
        # sumario, palavras_chave = modelo_mlp(transcricao_corrigida)  # Call the model with the corrected transcription
        sumario = "This is a placeholder summary."  # Replace with actual prediction
        palavras_chave = "These are placeholder keywords." # Replace with actual prediction
        # ----> End of placeholder prediction logic <----

        yield "Transcrição concluída.", str(sumario), str(palavras_chave), "100%", transcricao_corrigida  # Include corrected transcription in the output

    except Exception as e:
        # This is where the indented block needs to be
        print(f"An error occurred: {e}") # Print the error for debugging
        yield f"Erro: {e}", None, None, "0%", None  # Yield an error message and reset progress

iface = gr.Interface(
    fn=prever,
    inputs=gr.Audio(type="filepath", sources=["microphone", "upload"]),
    outputs=[
        gr.Textbox(lines=1, label="Status"),
        "text",
        "text",
        gr.Textbox(label="Progress"),
        gr.Textbox(lines=5, label="Transcrição Corrigida")  # Add a Textbox for the corrected transcription
    ],
    title="Gerador de Sumário e Palavras-chave",
    description="Grave um áudio para gerar um sumário e extrair palavras-chave."
)

iface.queue().launch()
# Out:
# ...
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://fd53cbf01f1106d80c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fd53cbf01f1106d80c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
